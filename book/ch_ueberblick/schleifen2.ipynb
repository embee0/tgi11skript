# %% [markdown]
# # Verschachtelte Schleifen

# %%
# TAG: remove-cell
from teachbook_utils.helpers import display_pyp5js_iframe, display_code_as_markdown, display_link_button
from teachbook_utils.helpers import EDITOR_URL, PRESENTATION_URL, FULLSCREEN_URL, EXT_PADDING

# Damit dieses Imports funktionieren, muss das Modul "teachbook_utils" gefunden werden können. 
# Das geht, wenn man "pip install -e ." im Hauptverzeichnis des Projekts ausführt. Das
# macht das Hauptverzeichnis als Python-Paket verfügbar. Man nennt das "Editable Install".

# %% [markdown]
# ## Unser allererstes Programm
# So sieht unser allererstes Programm in der Programmiersprache *Python* (und mit der Grafikbibliothek *Py5*) aus:

# %%
# TAG: remove-input
width = 300
height = 200

code = """
size(300, 200)         # Fenstergröße festlegen
circle(150, 100, 180)  # Kreis in die Mitte zeichnen
"""
display_code_as_markdown(code)
# Out:
# ```python
# size(300, 200)
# circle(150, 100, 180)
# ```

# %% [markdown]
# Wenn es ausgeführt wird, entsteht diese Grafik:

# %%
# TAG: remove-input
display_pyp5js_iframe(code, edit_button=True, width=width, height=height)
# Out:
#         <iframe
#             width="316"
#             height="216"
#             src="https://abav.lugaralgum.com/pyp5js/py5mode/presentation.html?sketch=c2l6ZSgzMDAsIDIwMCkKY2lyY2xlKDE1MCwgMTAwLCAxODAp"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Das Programm enthält nur zwei Befehle: Mit dem Befehl `size()` wird die Größe des Zeichenfensters festgelegt, und mit dem Befehl `circle()` wird ein Kreis in die Mitte des Fensters gezeichnet. Aber was bedeuten die Zahlen in den Klammern? Hast du ein Vermutung?
#
#
# ```{admonition} Aufgabe 1
# :class: tip
# 1 Dies ist eine einfache Aufgabe, um dich mit dem Aufbau eines Programms vertraut zu machen.
# ```

# %% [markdown]
# Und hier kommt schon das nächste Programm. Lies dir den Code genau durch und vergleiche ihn mit dem ersten Programm. Was ist anders, was ist gleich geblieben?

# %%
# TAG: remove-input
width = 200
height = 100

code = f"""
size({width}, {height})
circle(50, 50, 90)
circle(150, 50, 60)
"""

display_code_as_markdown(code)
# Out:
# ```python
# size(200, 100)
# circle(50, 50, 90)
# circle(150, 50, 60)
# ```

# %% [markdown]
# Stelle dir vor, welche Grafik dieses Programm erzeugen wird. Dann klappe hier die Lösung aus:

# %%
# TAG: remove-input hide-output
display_pyp5js_iframe(code, edit_button=False, width=width, height=height)
# Out:
#         <iframe
#             width="216"
#             height="116"
#             src="https://abav.lugaralgum.com/pyp5js/py5mode/presentation.html?sketch=c2l6ZSgyMDAsIDEwMCkKY2lyY2xlKDUwLCA1MCwgOTApCmNpcmNsZSgxNTAsIDUwLCA2MCk="
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
