# %% [markdown]
# # Iframes, Videos, H5P, etc.

# %% [markdown]
# ## Iframes für p5.js
# s. dort

# %% [markdown]
# ## Videos
#
# Hier ein Beispiel für ein Video, das mit der `video`-Direktive von TeachBooks eingebunden wird.
# ```{video} https://www.youtube.com/watch?v=FGlOlbNHiv8
# ```
